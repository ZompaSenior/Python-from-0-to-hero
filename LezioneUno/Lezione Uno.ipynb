# %%
from notebook.services.config import ConfigManager
cm = ConfigManager()
cm.update('livereveal', {
              'width': 1024,
              'height': 768,
              'scroll': True,
})
# Out:
# {'width': 1024, 'height': 768, 'scroll': True}

# %% [markdown]
# ![logo-ConoscereLinux_400x117.jpg](attachment:logo-ConoscereLinux_400x117.jpg)
# # Python from zero to hero
# ## Lezione 1
# ### Docente: Luca Zomparelli

# %% [markdown]
# - moduli e pachetti
# - tecniche avanzate per i cicli for
# - gestione file
# - with …
# - ancora sulle funzioni, gestioni avanzate dei parametri
# - i decoratori e i relativi fabbricatori

# %% [markdown]
# ## Moduli e pacchetti

# %% [markdown]
# ### Che cos'è un modulo di Python
# Un qualsiasi file con estensione .py

# %% [markdown]
# ### Che cos'è un pacchetto?
# Una cartella che contiene cartelle e moduli con un file denominato __init__.py
